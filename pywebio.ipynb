# %%
from pywebio.input import input, FLOAT
from pywebio.output import put_text

def bmi():
    height = input("Input your height(cm)：", type=FLOAT)
    weight = input("Input your weight(kg)：", type=FLOAT)

    BMI = weight / (height / 100) ** 2

    top_status = [(16, 'Severely underweight'),
                  (18.5, 'Underweight'),
                  (25, 'Normal'),
                  (30, 'Overweight'),
                  (35, 'Moderately obese'), (float('inf'), 'Severely obese')]

    for top, status in top_status:
        if BMI <= top:
            put_text('Your BMI: %.1f. Category: %s' % (BMI, status))
            break

if __name__ == '__main__':
    bmi()
# Out:
# ---------------------------------------------------------------------------
# SessionClosedException                    Traceback (most recent call last)
# <ipython-input-1-f845b2d04eff> in <module>
#      20
#      21 if __name__ == '__main__':
# ---> 22     bmi()
#
# <ipython-input-1-f845b2d04eff> in bmi()
#       3
#       4 def bmi():
# ----> 5     height = input("Input your height(cm)：", type=FLOAT)
#       6     weight = input("Input your weight(kg)：", type=FLOAT)
#       7
#
# c:\users\ancha\appdata\local\programs\python\python39\lib\site-packages\pywebio\input.py in input(label, type, validate, name, value, action, placeholder, required, readonly, datalist, help_text, **other_html_attrs)
#     223         return d
#     224
# --> 225     return single_input(item_spec, valid_func, preprocess_func)
#     226
#     227
#
# c:\users\ancha\appdata\local\programs\python\python39\lib\site-packages\pywebio\session\__init__.py in inner(*args, **kwargs)
#     269             return to_coroutine(gen)
#     270         else:
# --> 271             return run_as_function(gen)
#     272
#     273     return inner
#
# c:\users\ancha\appdata\local\programs\python\python39\lib\site-packages\pywebio\utils.py in run_as_function(gen)
#     293     while 1:
#     294         try:
# --> 295             res = gen.send(res)
#     296         except StopIteration as e:
#     297             if len(e.args) == 1:
#
# c:\users\ancha\appdata\local\programs\python\python39\lib\site-packages\pywebio\io_ctrl.py in single_input(item_spec, valid_func, preprocess_func)
#     180
#     181     spec = dict(label=label, inputs=[item_spec])
# --> 182     data = yield input_control(spec, {name: preprocess_func}, {name: valid_func})
#     183     return data[name]
#     184
#
# c:\users\ancha\appdata\local\programs\python\python39\lib\site-packages\pywebio\session\__init__.py in inner(*args, **kwargs)
#     269             return to_coroutine(gen)
#     270         else:
# --> 271             return run_as_function(gen)
#     272
#     273     return inner
#
# c:\users\ancha\appdata\local\programs\python\python39\lib\site-packages\pywebio\utils.py in run_as_function(gen)
#     293     while 1:
#     294         try:
# --> 295             res = gen.send(res)
#     296         except StopIteration as e:
#     297             if len(e.args) == 1:
#
# c:\users\ancha\appdata\local\programs\python\python39\lib\site-packages\pywebio\io_ctrl.py in input_control(spec, preprocess_funcs, item_valid_funcs, form_valid_funcs)
#     196     send_msg('input_group', spec)
#     197
# --> 198     data = yield input_event_handle(item_valid_funcs, form_valid_funcs, preprocess_funcs)
#     199
#     200     send_msg('destroy_form')
#
# c:\users\ancha\appdata\local\programs\python\python39\lib\site-packages\pywebio\session\__init__.py in inner(*args, **kwargs)
#     269             return to_coroutine(gen)
#     270         else:
# --> 271             return run_as_function(gen)
#     272
#     273     return inner
#
# c:\users\ancha\appdata\local\programs\python\python39\lib\site-packages\pywebio\utils.py in run_as_function(gen)
#     293     while 1:
#     294         try:
# --> 295             res = gen.send(res)
#     296         except StopIteration as e:
#     297             if len(e.args) == 1:
#
# c:\users\ancha\appdata\local\programs\python\python39\lib\site-packages\pywebio\io_ctrl.py in input_event_handle(item_valid_funcs, form_valid_funcs, preprocess_funcs)
#     235     """
#     236     while True:
# --> 237         event = yield next_client_event()
#     238         event_name, event_data = event['event'], event['data']
#     239         if event_name == 'input_event':
#
# c:\users\ancha\appdata\local\programs\python\python39\lib\site-packages\pywebio\session\__init__.py in inner(*args, **kwargs)
#     269             return to_coroutine(gen)
#     270         else:
# --> 271             return run_as_function(gen)
#     272
#     273     return inner
#
# c:\users\ancha\appdata\local\programs\python\python39\lib\site-packages\pywebio\utils.py in run_as_function(gen)
#     293     while 1:
#     294         try:
# --> 295             res = gen.send(res)
#     296         except StopIteration as e:
#     297             if len(e.args) == 1:
#
# c:\users\ancha\appdata\local\programs\python\python39\lib\site-packages\pywebio\session\__init__.py in next_client_event()
#     276 @chose_impl
#     277 def next_client_event():
# --> 278     res = yield get_current_session().next_client_event()
#     279     return res
#     280
#
# c:\users\ancha\appdata\local\programs\python\python39\lib\site-packages\pywebio\session\threadbased.py in next_client_event(self)
#     130         event = event_mq.get()
#     131         if event is None:
# --> 132             raise SessionClosedException
#     133         return event
#     134
#
# SessionClosedException:
