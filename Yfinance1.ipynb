# %%
import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime

# %%
df1 = yf.download('BTC-USD', 
                      start='2020-01-01', 
                      end='2021-05-10', 
                      progress=False, index_col="Date")
df1.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2019-12-31   7294.438965   7335.290039   7169.777832   7193.599121
# 2020-01-01   7194.892090   7254.330566   7174.944336   7200.174316
# 2020-01-02   7202.551270   7212.155273   6935.270020   6985.470215
# 2020-01-03   6984.428711   7413.715332   6914.996094   7344.884277
# 2020-01-04   7345.375488   7427.385742   7309.514160   7410.656738
# ...                  ...           ...           ...           ...
# 2021-05-05  53252.164062  57911.363281  52969.054688  57424.007812
# 2021-05-06  57441.308594  58363.316406  55382.507812  56396.515625
# 2021-05-07  56413.953125  58606.632812  55321.847656  57356.402344
# 2021-05-08  57352.765625  59464.613281  56975.210938  58803.777344
# 2021-05-09  58877.390625  59210.882812  56482.003906  58232.316406
#
#                Adj Close       Volume
# Date
# 2019-12-31   7193.599121  21167946112
# 2020-01-01   7200.174316  18565664997
# ...

# %%
ticker = yf.Ticker('BTC-USD')

# %%
df = ticker.history(period = "max")
df.tail()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-05-19  42944.976562  43546.117188  30681.496094  37002.441406
# 2021-05-20  36753.667969  42462.984375  35050.617188  40782.738281
# 2021-05-21  40596.949219  42172.171875  33616.453125  37304.691406
# 2021-05-22  37371.031250  38831.054688  35383.683594  37536.632812
# 2021-05-23  37026.246094  38265.753906  34806.074219  34806.074219
#
#                   Volume  Dividends  Stock Splits
# Date
# 2021-05-19  126358098747          0             0
# 2021-05-20   88281943359          0             0
# 2021-05-21   82051616861          0             0
# 2021-05-22   57377273240          0             0
# 2021-05-23   50414129152          0             0

# %%
plt.figure(figsize=(10,6))

df['Close'].plot(title="stock price")
# Out:
# <AxesSubplot:title={'center':'stock price'}, xlabel='Date'>

# %%
type(ticker.info)
# Out:
# dict

# %%
stockinfo = ticker.info

for key,value in stockinfo.items():
    print(key, ":", value)
# Out:
# zip : 95014
# sector : Technology
# fullTimeEmployees : 100000
# ...

# %%
ticker.splits
# Out:
# Series([], Name: Stock Splits, dtype: int64)

# %%
ticker.financials
# Out:
#                                             2020-09-26      2019-09-28  \
# Research Development                     18752000000.0   16217000000.0
# Effect Of Accounting Charges                      None            None
# Income Before Tax                        67091000000.0   65737000000.0
# Minority Interest                                 None            None
# Net Income                               57411000000.0   55256000000.0
# Selling General Administrative           19916000000.0   18245000000.0
# Gross Profit                            104956000000.0   98392000000.0
# Ebit                                     66288000000.0   63930000000.0
# Operating Income                         66288000000.0   63930000000.0
# Other Operating Expenses                          None            None
# Interest Expense                         -2873000000.0   -3576000000.0
# Extraordinary Items                               None            None
# ...

# %%
ticker.major_holders
# Out:
#         0                                      1
# 0   0.07%        % of Shares Held by All Insider
# 1  58.70%       % of Shares Held by Institutions
# 2  58.74%        % of Float Held by Institutions
# 3    4927  Number of Institutions Holding Shares

# %%
ticker.recommendations
# Out:
#                                        Firm      To Grade From Grade Action
# Date
# 2012-02-09 08:17:00       Canaccord Genuity           Buy              main
# 2012-03-08 07:33:00          FBN Securities    Outperform              main
# 2012-03-13 06:08:00               Jefferies           Buy              main
# 2012-03-14 06:13:00          Morgan Stanley    Overweight              main
# 2012-03-14 08:21:00       Canaccord Genuity           Buy              main
# ...                                     ...           ...        ...    ...
# 2021-04-29 13:17:44       Canaccord Genuity           Buy              main
# 2021-04-29 13:20:06           Credit Suisse       Neutral              main
# 2021-04-29 13:40:32  Monness, Crespi, Hardt           Buy              main
# 2021-04-29 14:01:59                Barclays  Equal-Weight              main
# 2021-05-19 10:59:15                Barclays  Equal-Weight              main
#
# [790 rows x 4 columns]

# %%
ticker.institutional_holders
# Out:
#                                 Holder      Shares Date Reported   % Out  \
# 0           Vanguard Group, Inc. (The)  1239382735    2021-03-30  0.0743
# 1                       Blackrock Inc.  1055005602    2021-03-30  0.0632
# 2              Berkshire Hathaway, Inc   887135554    2021-03-30  0.0532
# 3             State Street Corporation   622994241    2021-03-30  0.0373
# 4                             FMR, LLC   344952148    2021-03-30  0.0207
# 5        Geode Capital Management, LLC   249806296    2021-03-30  0.0150
# 6        Price (T.Rowe) Associates Inc   200552368    2021-03-30  0.0120
# 7           Northern Trust Corporation   198866995    2021-03-30  0.0119
# 8    Norges Bank Investment Management   167580974    2020-12-30  0.0100
# 9  Bank Of New York Mellon Corporation   154693732    2021-03-30  0.0093
#
#           Value
# 0  151390601080
# 1  128868934284
# 2  108363607921
# 3   76098746538
# 4   42135904878
# 5   30513839056
# 6   24497471751
# 7   24291603439
# ...

# %%
type(ticker.dividends)
ticker.dividends
# Out:
# Series([], Name: Dividends, dtype: int64)

# %%
plt.figure(figsize=(16,10))

plt.title("Stock price")

sns.lineplot(data = df)
# Out:
# <AxesSubplot:title={'center':'Stock price'}, xlabel='Date'>

# %%
plt.figure(figsize=(16,10))
sns.lineplot(data=df['High'], label="High")
sns.lineplot(data=df['Low'], label="Low")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='High'>

# %%
plt.figure(figsize=(16,10))
sns.scatterplot(x=df['Volume'], y=df['Close'])
# Out:
# <AxesSubplot:xlabel='Volume', ylabel='Close'>

# %%
df.tail(1)
# Out:
#                  Open       High        Low      Close  Volume  Dividends  \
# Date
# 2021-05-20  99.110001  99.110001  99.110001  99.110001       0          0
#
#             Stock Splits
# Date
# 2021-05-20             0

# %%
stocks = ['btc', 'eth', 'neo','eos', 'dot', 'bnb', 'ada','xtz']

df3 = pd.DataFrame()

for stock in stocks:
    df3[stocks] = yf.Ticker(stock).history(period = "max").Close
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-7be4ce2a63c4> in <module>
#       4
#       5 for stock in stocks:
# ----> 6     df3[stocks] = yf.Ticker(stock).history(period = "max").Close
#
# c:\users\ancha\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3158             self._setitem_frame(key, value)
#    3159         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3160             self._setitem_array(key, value)
#    3161         else:
#    3162             # set column
#
# c:\users\ancha\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    3196                 )[1]
#    3197                 self._check_setitem_copy()
# -> 3198                 self.iloc[:, indexer] = value
#    3199
# ...

# %%
plt.figure(figsize=(14,8))

plt.plot(df3)

plt.xlabel('Year')
plt.ylabel('Price')

plt.show()

# %%
sns.lineplot(data= df3)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
list(df.columns)
# Out:
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
