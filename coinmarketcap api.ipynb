# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd
import numpy as np
import pprint

# %%
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
    'limit' : '1000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'b78b6aa3-2899-4f3e-8c1e-55ba0dbd9a44',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data1 = json.loads(response.text)
  print(data1)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2021-05-31T20:03:07.421Z', 'error_code': 0, 'error_message': None, 'elapsed': 112, 'credit_count': 5, 'notice': None, 'total_count': 5430}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 9738, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channels', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'arrington-xrp-capital', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures', 'galaxy-digital-portfolio', 'huobi-capital', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-xzy-screener'], 'max_supply': 21000000, 'circulating_supply': 18723018, 'total_supply': 18723018, 'platform': None, 'cmc_rank': 1, 'last_updated': '2021-05-31T20:02:02.000Z', 'quote': {'USD': {'price': 36924.76505162183, 'volume_24h': 37958553656.49961, 'percent_change_1h': 0.47006729, 'percent_change_24h': 2.39924732, 'percent_change_7d': -7.30604886, 'percent_change_30d': -36.08665245, 'percent_change_60d': -37.70336787, 'percent_change_90d': -22.31800034, 'market_cap': 691343040707.2864, 'last_updated': '2021-05-31T20:02:02.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 6015, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['mineable', 'pow', 'smart-contracts', 'ethereum', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'arrington-xrp-capital', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures', 'hashkey-capital-portfolio', 'kinetic-capital', 'huobi-capital', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-xzy-screener'], 'max_supply': None, 'circulating_supply': 116102137.499, 'total_supply': 116102137.499, 'platform': None, 'cmc_rank': 2, 'last_updated': '2021-05-31T20:02:02.000Z', 'quote': {'USD': {'price': 2633.061720414342, 'volume_24h': 29738229005.087494, 'percent_change_1h': 1.24332451, 'percent_change_24h': 8.0768826, 'percent_change_7d': -1.19429355, 'percent_change_30d': -10.01583472, 'percent_change_60d': 32.83140891, 'percent_change_90d': 77.93468783, 'market_cap': 305704093906.8994, 'last_updated': '2021-05-31T20:02:02.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 13331, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['store-of-value', 'payments', 'stablecoin', 'stablecoin-asset-backed', 'solana-ecosystem'], 'max_supply': None, 'circulating_supply': 61783335673.66168, 'total_supply': 63476291004.32977, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7'}, 'cmc_rank': 3, 'last_updated': '2021-05-31T20:01:11.000Z', 'quote': {'USD': {'price': 1.00057870465107, 'volume_24h': 85231835001.70856, 'percent_change_1h': -0.02477959, 'percent_change_24h': 0.03498922, 'percent_change_7d': -0.07762118, 'percent_change_30d': 0.06309877, 'percent_change_60d': 0.02409969, 'percent_change_90d': 0.004137, 'market_cap': 61819089977.37464, 'last_updated': '2021-05-31T20:01:11.000Z'}}}, {'id': 2010, 'name': 'Cardano', 'symbol': 'ADA', 'slug': 'cardano', 'num_market_pairs': 273, 'date_added': '2017-10-01T00:00:00.000Z', 'tags': ['mineable', 'dpos', 'pos', 'platf ...

# %%
pprint.pprint(data1)
# Out:
# {'data': [{'circulating_supply': 18723018,
#            'cmc_rank': 1,
#            'date_added': '2013-04-28T00:00:00.000Z',
#            'id': 1,
#            'last_updated': '2021-05-31T20:02:02.000Z',
#            'max_supply': 21000000,
#            'name': 'Bitcoin',
#            'num_market_pairs': 9738,
#            'platform': None,
#            'quote': {'USD': {'last_updated': '2021-05-31T20:02:02.000Z',
#                              'market_cap': 691343040707.2864,
#                              'percent_change_1h': 0.47006729,
#                              'percent_change_24h': 2.39924732,
#                              'percent_change_30d': -36.08665245,
#                              'percent_change_60d': -37.70336787,
#                              'percent_change_7d': -7.30604886,
#                              'percent_change_90d': -22.31800034,
#                              'price': 36924.76505162183,
#                              'volume_24h': 37958553656.49961}},
#            'slug': 'bitcoin',
#            'symbol': 'BTC',
#            'tags': ['mineable',
#                     'pow',
#                     'sha-256',
#                     'store-of-value',
#                     'state-channels',
#                     'coinbase-ventures-portfolio',
#                     'three-arrows-capital-portfolio',
#                     'polychain-capital-portfolio',
#                     'binance-labs-portfolio',
#                     'arrington-xrp-capital',
#                     'blockchain-capital-portfolio',
#                     'boostvc-portfolio',
#                     'cms-holdings-portfolio',
#                     'dcg-portfolio',
#                     'dragonfly-capital-portfolio',
#                     'electric-capital-portfolio',
#                     'fabric-ventures-portfolio',
#                     'framework-ventures',
#                     'galaxy-digital-portfolio',
#                     'huobi-capital',
#                     'alameda-research-portfolio',
#                     'a16z-portfolio',
#                     '1confirmation-portfolio',
#                     'winklevoss-capital',
#                     'usv-portfolio',
#                     'placeholder-ventures-portfolio',
#                     'pantera-capital-portfolio',
#                     'multicoin-capital-portfolio',
#                     'paradigm-xzy-screener'],
#            'total_supply': 18723018},
#           {'circulating_supply': 116102137.499,
#            'cmc_rank': 2,
#            'date_added': '2015-08-07T00:00:00.000Z',
#            'id': 1027,
#            'last_updated': '2021-05-31T20:02:02.000Z',
#            'max_supply': None,
#            'name': 'Ethereum',
#            'num_market_pairs': 6015,
#            'platform': None,
#            'quote': {'USD': {'last_updated': '2021-05-31T20:02:02.000Z',
#                              'market_cap': 305704093906.8994,
#                              'percent_change_1h': 1.24332451,
#                              'percent_change_24h': 8.0768826,
#                              'percent_change_30d': -10.01583472,
#                              'percent_change_60d': 32.83140891,
#                              'percent_change_7d': -1.19429355,
#                              'percent_change_90d': 77.93468783,
#                              'price': 2633.061720414342,
#                              'volume_24h': 29738229005.087494}},
#            'slug': 'ethereum',
#            'symbol': 'ETH',
#            'tags': ['mineable',
#                     'pow',
#                     'smart-contracts',
#                     'ethereum',
#                     'coinbase-ventures-portfolio',
#                     'three-arrows-capital-portfolio',
#                     'polychain-capital-portfolio',
#                     'binance-labs-portfolio',
#                     'arrington-xrp-capital',
#                     'blockchain-capital-portfolio',
#                     'boostvc-portfolio',
#                     'cms-holdings-portfolio',
#                     'dcg-portfolio',
#                     'dragonfly-capital-portfolio',
#                     'electric-capital-portfolio',
#                     'fabric-ventures-portfolio',
#                     'framework-ventures',
#                     'hashkey-capital-portfolio',
#                     'kinetic-capital',
#                     'huobi-capital',
#                     'alameda-research-portfolio',
#                     'a16z-portfolio',
#                     '1confirmation-portfolio',
#                     'winklevoss-capital',
#                     'usv-portfolio',
#                     'placeholder-ventures-portfolio',
#                     'pantera-capital-portfolio',
#                     'multicoin-capital-portfolio',
#                     'paradigm-xzy-screener'],
#            'total_supply': 116102137.499},
#           {'circulating_supply': 61783335673.66168,
#            'cmc_rank': 3,
#            'date_added': '2015-02-25T00:00:00.000Z',
#            'id': 825,
#            'last_updated': '2021-05-31T20:01:11.000Z',
#            'max_supply': None,
#            'name': 'Tether',
#            'num_market_pairs': 13331,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7'},
#            'quote': {'USD': {'last_updated': '2021-05-31T20:01:11.000Z',
#                              'market_cap': 61819089977.37464,
#                              'percent_change_1h': -0.02477959,
#                              'percent_change_24h': 0.03498922,
#                              'percent_change_30d': 0.06309877,
#                              'percent_change_60d': 0.02409969,
#                              'percent_change_7d': -0.07762118,
#                              'percent_change_90d': 0.004137,
#                              'price': 1.00057870465107,
#                              'volume_24h': 85231835001.70856}},
#            'slug': 'tether',
#            'symbol': 'USDT',
#            'tags': ['store-of-value',
#                     'payments',
#                     'stablecoin',
#                     'stablecoin-asset-backed',
#                     'solana-ecosystem'],
#            'total_supply': 63476291004.32977},
#           {'circulating_supply': 31948309440.7478,
#            'cmc_rank': 4,
#            'date_added': '2017-10-01T00:00:00.000Z',
#            'id': 2010,
#            'last_updated': '2021-05-31T20:01:13.000Z',
#            'max_supply': 45000000000,
#            'name': 'Cardano',
#            'num_market_pairs': 273,
#            'platform': None,
#            'quote': {'USD': {'last_updated': '2021-05-31T20:01:13.000Z',
#                              'market_cap': 53366853749.17589,
#                              'percent_change_1h': 1.03128417,
#                              'percent_change_24h': 3.03048675,
#                              'percent_change_30d': 25.33177381,
#                              'percent_change_60d': 40.26153597,
#                              'percent_change_7d': 5.39022862,
#                              'percent_change_90d': 39.81139203,
#                              'price': 1.67041244696066,
#                              'volume_24h': 4353971142.318094}},
#            'slug': 'cardano',
#            'symbol': 'ADA',
#            'tags': ['mineable',
#                     'dpos',
#                     'pos',
#                     'platform',
#                     'research',
#                     'smart-contracts',
#                     'staking',
#                     'binance-chain'],
#            'total_supply': 45000000000},
#           {'circulating_supply': 153432897,
#            'cmc_rank': 5,
#            'date_added': '2017-07-25T00:00:00.000Z',
#            'id': 1839,
#            'last_updated': '2021-05-31T20:01:11.000Z',
#            'max_supply': 170532785,
#            'name': 'Binance Coin',
#            'num_market_pairs': 616,
#            'platform': None,
#            'quote': {'USD': {'last_updated': '2021-05-31T20:01:11.000Z',
#                              'market_cap': 53193745814.70114,
#                              'percent_change_1h': 1.13917165,
#                              'percent_change_24h': 4.91409853,
#                              'percent_change_30d': -44.21781134,
#                              'percent_change_60d': 5.4826378,
#                              'percent_change_7d': -0.76509704,
#                              'percent_change_90d': 50.52183909,
#                              'price': 346.6906175583789,
#                              'volume_24h': 3749862079.725591}},
#            'slug': 'binance-coin',
#            'symbol': 'BNB',
#            'tags': ['marketplace',
#                     'centralized-exchange',
#                     'payments',
#                     'binance-smart-chain',
#                     'alameda-research-portfolio',
#                     'multicoin-capital-portfolio'],
#            'total_supply': 169432897},
#           {'circulating_supply': 46143602688,
#            'cmc_rank': 6,
#            'date_added': '2013-08-04T00:00:00.000Z',
#            'id': 52,
#            'last_updated': '2021-05-31T20:02:03.000Z',
#            'max_supply': 100000000000,
#            'name': 'XRP',
#            'num_market_pairs': 683,
#            'platform': None,
#            'quote': {'USD': {'last_updated': '2021-05-31T20:02:03.000Z',
#                              'market_cap': 46014989351.76502,
#                              'percent_change_1h': 0.83291036,
#                              'percent_change_24h': 11.17245519,
#                              'percent_change_30d': -36.86195161,
#                              'percent_change_60d': 73.79098175,
#                              'percent_change_7d': 5.95926294,
#                              'percent_change_90d': 132.07289715,
#                              'price': 0.99721275910976,
#                              'volume_24h': 6163940670.431636}},
#            'slug': 'xrp',
#            'symbol': 'XRP',
#            'tags': ['medium-of-exchange',
#                     'enterprise-solutions',
#                     'binance-chain',
#                     'arrington-xrp-capital',
#                     'galaxy-digital-portfolio',
#                     'a16z-portfolio',
#                     'pantera-capital-portfolio'],
#            'total_supply': 99990424619},
#           {'circulating_supply': 129826876507.56114,
#            'cmc_rank': 7,
#            'date_added': '2013-12-15T00:00:00.000Z',
#            'id': 74,
#            'last_updated': '2021-05-31T20:02:03.000Z',
#            'max_supply': None,
#            'name': 'Dogecoin',
#            'num_market_pairs': 370,
#            'platform': None,
#            'quote': {'USD': {'last_updated': '2021-05-31T20:02:03.000Z',
#                              'market_cap': 42031257698.445816,
#                              'percent_change_1h': 2.76713414,
#                              'percent_change_24h': 6.10415743,
#                              'percent_change_30d': -11.49257376,
#                              'percent_change_60d': 452.48339149,
#                              'percent_change_7d': -10.02596156,
#                              'percent_change_90d': 552.91003374,
#                              'price': 0.32374850900767,
#                              'volume_24h': 2191153641.12737}},
#            'slug': 'dogecoin',
#            'symbol': 'DOGE',
#            'tags': ['mineable',
#                     'pow',
#                     'scrypt',
#                     'medium-of-exchange',
#                     'memes',
#                     'payments'],
#            'total_supply': 129826876507.56114},
#           {'circulating_supply': 22619979204.737343,
#            'cmc_rank': 8,
#            'date_added': '2018-10-08T00:00:00.000Z',
#            'id': 3408,
#            'last_updated': '2021-05-31T20:02:05.000Z',
#            'max_supply': None,
#            'name': 'USD Coin',
#            'num_market_pairs': 1052,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#            'quote': {'USD': {'last_updated': '2021-05-31T20:02:05.000Z',
#                              'market_cap': 22624874783.447296,
#                              'percent_change_1h': -0.00970584,
#                              'percent_change_24h': 0.08272011,
#                              'percent_change_30d': 0.02211562,
#                              'percent_change_60d': -0.05240628,
#                              'percent_change_7d': 0.0290606,
#                              'percent_change_90d': 0.01126405,
#                              'price': 1.00021642719764,
#                              'volume_24h': 2269777490.6618533}},
#            'slug': 'usd-coin',
#            'symbol': 'USDC',
#            'tags': ['medium-of-exchange',
#                     'stablecoin',
#                     'stablecoin-asset-backed'],
#            'total_supply': 22619979204.737343},
#           {'circulating_supply': 943500497.4944279,
#            'cmc_rank': 9,
#            'date_added': '2020-08-19T00:00:00.000Z',
#            'id': 6636,
#            'last_updated': '2021-05-31T20:02:06.000Z',
#            'max_supply': None,
#            'name': 'Polkadot',
#            'num_market_pairs': 201,
#            'platform': None,
#            'quote': {'USD': {'last_updated': '2021-05-31T20:02:06.000Z',
#                              'market_cap': 21048840041.628967,
#                              'percent_change_1h': 1.10908431,
#                              'percent_change_24h': 7.71728857,
#                              'percent_change_30d': -40.09691687,
#                              'percent_change_60d': -41.31143995,
#                              'percent_change_7d': -3.14874624,
#                              'percent_change_90d': -36.20101325,
#                              'price': 22.30930465593451,
#                              'volume_24h': 2422054821.458213}},
#            'slug': 'polkadot-new',
#            'symbol': 'DOT',
#            'tags': ['substrate',
#                     'polkadot',
#                     'binance-chain',
#                     'polkadot-ecosystem',
#                     'three-arrows-capital-portfolio',
#                     'polychain-capital-portfolio',
#                     'blockchain-capital-portfolio',
#                     'boostvc-portfolio',
#                     'cms-holdings-portfolio',
#                     'coinfund-portfolio',
#                     'fabric-ventures-portfolio',
#                     'fenbushi-capital-portfolio',
#                     'hashkey-capital-portfolio',
#                     'kinetic-capital',
#                     '1confirmation-portfolio',
#                     'placeholder-ventures-portfolio',
#                     'pantera-capital-portfolio',
#                     'exnetwork-capital-portfolio'],
#            'total_supply': 1079024612.3486156},
#           {'circulating_supply': 565712820.738249,
#            'cmc_rank': 10,
#            'date_added': '2020-09-17T00:00:00.000Z',
#            'id': 7083,
#            'last_updated': '2021-05-31T20:01:13.000Z',
#            'max_supply': 1000000000,
#            'name': 'Uniswap',
#            'num_market_pairs': 272,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#            'quote': {'USD': {'last_updated': '2021-05-31T20:01:13.000Z',
#                              'market_cap': 15586777117.914238,
#                              'percent_change_1h': 1.83759398,
#                              'percent_change_24h': 5.78614077,
#                              'percent_change_30d': -31.13752977,
#                              'percent_change_60d': -5.61268833,
#                              'percent_change_7d': 10.69060849,
#                              'percent_change_90d': 11.13990845,
#                              'price': 27.5524551442438,
#                              'volume_24h': 1037698880.320797}},
#            'slug': 'uniswap',
#            'symbol': 'UNI',
#            'tags': ['decentralized-exchange',
#                     'defi',
#                     'dao',
#                     'yield-farming',
#                     'amm',
#                     'coinbase-ventures-portfolio',
#                     'three-arrows-capital-portfolio',
#                     'governance',
#                     'blockchain-capital-portfolio',
#                     'defiance-capital',
#                     'alameda-research-portfolio',
#                     'a16z-portfolio',
#                     'pantera-capital-portfolio',
#                     'parafi-capital',
#                     'paradigm-xzy-screener'],
#            'total_supply': 1000000000},
#           {'circulating_supply': 124048742.19,
#            'cmc_rank': 11,
#            'date_added': '2021-03-23T00:00:00.000Z',
#            'id': 8916,
#            'last_updated': '2021-05-31T20:01:08.000Z',
#            'max_supply': None,
#            'name': 'Internet Computer',
#            'num_market_pairs': 31,
#            'platform': None,
#            'quote': {'USD': {'last_updated': '2021-05-31T20:01:08.000Z',
#                              'market_cap': 13952961579.266607,
#                              'percent_change_1h': -1.31984242,
#                              'percent_change_24h': -2.90558425,
#                              'percent_change_30d': 0,
#                              'percent_change_60d': 0,
#                              'percent_change_7d': -24.75743042,
#                              'percent_change_90d': 0,
#                              'price': 112.47966995018353,
#                              'volume_24h': 188392925.76440802}},
#            'slug': 'internet-computer',
#            'symbol': 'ICP',
#            'tags': ['platform',
#                     'distributed-computing',
#                     'polychain-capital-portfolio',
#                     'exnetwork-capital-portfolio'],
#            'total_supply': 469290320.87930804},
#           {'circulating_supply': 429509553.9174637,
#            'cmc_rank': 12,
#            'date_added': '2017-09-20T00:00:00.000Z',
#            'id': 1975,
#            'last_updated': '2021-05-31T20:01:13.000Z',
#            'max_supply': 1000000000,
#            'name': 'Chainlink',
#            'num_market_pairs': 521,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x514910771af9ca656af840dff83e8264ecf986ca'},
#            'quote': {'USD': {'last_updated': '2021-05-31T20:01:13.000Z',
#                              'market_cap': 13290658836.044882,
#                              'percent_change_1h': 1.94655356,
#                              'percent_change_24h': 10.94338789,
#                              'percent_change_30d': -24.53421442,
#                              'percent_change_60d': 1.19571017,
#                              'percent_change_7d': 19.44896494,
#                              'percent_change_90d': 11.13470967,
#                              'price': 30.94380256463135,
#                              'volume_24h': 2464695023.512997}},
#            'slug': 'chainlink',
#            'symbol': 'LINK',
#            'tags': ['platform',
#                     'defi',
#                     'oracles',
#                     'smart-contracts',
#                     'substrate',
#                     'polkadot',
#                     'polkadot-ecosystem',
#                     'solana-ecosystem',
#                     'framework-ventures',
#                     'polygon-ecosystem'],
#            'total_supply': 1000000000},
#           {'circulating_supply': 18751550,
#            'cmc_rank': 13,
#            'date_added': '2017-07-23T00:00:00.000Z',
#            'id': 1831,
#            'last_updated': '2021-05-31T20:01:09.000Z',
#            'max_supply': 21000000,
#            'name': 'Bitcoin Cash',
#            'num_market_pairs': 596,
#            'platform': None,
#            'quote': {'USD': {'last_updated': '2021-05-31T20:01:09.000Z',
#                              'market_cap': 13131649581.253912,
#                              'percent_change_1h': 0.57225049,
#                              'percent_change_24h': 4.9616846,
#                              'percent_change_30d': -29.94122434,
#                              'percent_change_60d': 25.2761826,
#                              'percent_change_7d': 0.87213553,
#                              'percent_change_90d': 37.35179925,
#                              'price': 700.2967531352828,
#                              'volume_24h': 2757314870.6321583}},
#            'slug': 'bitcoin-cash',
#            'symbol': 'BCH',
#            'tags': ['mineable',
#                     'pow',
#                     'sha-256',
#                     'marketplace',
#                     'medium-of-exchange',
#                     'store-of-value',
#                     'enterprise-solutions',
#                     'payments',
#                     'binance-chain'],
#            'total_supply': 18751550},
#           {'circulating_supply': 66752414.51538747,
#            'cmc_rank': 14,
#            'date_added': '2013-04-28T00:00:00.000Z',
#            'id': 2,
#            'last_updated': '2021-05-31T20:02:02.000Z',
#            'max_supply': 84000000,
#            'name': 'Litecoin',
#            'num_market_pairs': 755,
#            'platform': None,
#            'quote': {'USD': {'last_updated': '2021-05-31T20:02:02.000Z',
#                              'market_cap': 12274202955.649614,
#                              'percent_change_1h': 0.89481374,
#                              'percent_change_24h': 5.81198219,
#                              'percent_change_30d': -32.81227774,
#                              'percent_change_60d': -9.53520022,
#                              'percent_change_7d': 1.30615862,
#                              'percent_change_90d': 6.86046607,
#                              'price': 183.87653906991216,
#                              'volume_24h': 3296340280.5836253}},
#            'slug': 'litecoin',
#            'symbol': 'LTC',
#            'tags': ['mineable',
#                     'pow',
#                     'scrypt',
#                     'medium-of-exchange',
#                     'binance-chain'],
#            'total_supply': 66752414.51538747},
#           {'circulating_supply': 6211590053,
#            'cmc_rank': 15,
#            'date_added': '2019-04-28T00:00:00.000Z',
#            'id': 3890,
#            'last_updated': '2021-05-31T20:01:11.000Z',
#            'max_supply': 10000000000,
#            'name': 'Polygon',
#            'num_market_pairs': 132,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0'},
#            'quote': {'USD': {'last_updated': '2021-05-31T20:01:11.000Z',
#                              'market_cap': 11397621514.021717,
#                              'percent_change_1h': 0.34635076,
#                              'percent_change_24h': -2.22292423,
#                              'percent_change_30d': 127.17564018,
#                              'percent_change_60d': 401.997625,
#                              'percent_change_7d': 3.69323208,
#                              'percent_change_90d': 733.19829712,
#                              'price': 1.83489596331571,
#                              'volume_24h': 3105414033.681194}},
#            'slug': 'polygon',
#            'symbol': 'MATIC',
#            'tags': ['platform',
#                     'enterprise-solutions',
#                     'state-channels',
#                     'coinbase-ventures-portfolio',
#                     'binance-launchpad',
#                     'binance-labs-portfolio',
#                     'polygon-ecosystem'],
#            'total_supply': 10000000000},
#           {'circulating_supply': 23113746393.17161,
#            'cmc_rank': 16,
#            'date_added': '2014-08-05T00:00:00.000Z',
#            'id': 512,
#            'last_updated': '2021-05-31T20:02:07.000Z',
#            'max_supply': 50001806812,
#            'name': 'Stellar',
#            'num_market_pairs': 347,
#            'platform': None,
#            'quote': {'USD': {'last_updated': '2021-05-31T20:02:07.000Z',
#                              'market_cap': 9070941155.856815,
#                              'percent_change_1h': 0.4480173,
#                              'percent_change_24h': 4.50280312,
#                              'percent_change_30d': -25.43375312,
#                              'percent_change_60d': -6.92477541,
#                              'percent_change_7d': -10.76991382,
#                              'percent_change_90d': -2.48936623,
#                              'price': 0.39244789665671,
#                              'volume_24h': 1006316688.2790542}},
#            'slug': 'stellar',
#            'symbol': 'XLM',
#            'tags': ['medium-of-exchange',
#                     'enterprise-solutions',
#                     'decentralized-exchange',
#                     'smart-contracts',
#                     'hashkey-capital-portfolio'],
#            'total_supply': 50001803158.544525},
#           {'circulating_supply': 8656430109.93,
#            'cmc_rank': 17,
#            'date_added': '2019-09-20T00:00:00.000Z',
#            'id': 4687,
#            'last_updated': '2021-05-31T20:01:08.000Z',
#            'max_supply': None,
#            'name': 'Binance USD',
#            'num_market_pairs': 752,
#            'platform': {'id': 1839,
#                         'name': 'Binance Chain',
#                         'slug': 'binance-coin',
#                         'symbol': 'BNB',
#                         'token_address': 'BUSD-BD1'},
#            'quote': {'USD': {'last_updated': '2021-05-31T20:01:08.000Z',
#                              'market_cap': 8657297128.590395,
#                              'percent_change_1h': -0.02943931,
#                              'percent_change_24h': 0.0694145,
#                              'percent_change_30d': 0.01586654,
#                              'percent_change_60d': -0.07008964,
#                              'percent_change_7d': 0.00267576,
#                              'percent_change_90d': 0.0300219,
#                              'price': 1.00010015891648,
#                              'volume_24h': 5689140350.827238}},
#            'slug': 'binance-usd',
#            'symbol': 'BUSD',
#            'tags': ['store-of-value',
#                     'stablecoin',
#                     'stablecoin-asset-backed',
#                     'binance-chain',
#                     'binance-smart-chain'],
#            'total_supply': 8656430109.93},
#           {'circulating_supply': 272637427.57725775,
#            'cmc_rank': 18,
#            'date_added': '2020-04-10T00:00:00.000Z',
#            'id': 5426,
#            'last_updated': '2021-05-31T20:02:05.000Z',
#            'max_supply': None,
#            'name': 'Solana',
#            'num_market_pairs': 53,
#            'platform': None,
#            'quote': {'USD': {'last_updated': '2021-05-31T20:02:05.000Z',
#                              'market_cap': 8663211248.758207,
#                              'percent_change_1h': 0.30950774,
#                              'percent_change_24h': 9.45281163,
#                              'percent_change_30d': -35.27712313,
#                              'percent_change_60d': 65.23811278,
#                              'percent_change_7d': -0.9935485,
#                              'percent_change_90d': 132.33937079,
#                              'price': 31.77557581049028,
#                              'volume_24h': 518199312.2697693}},
#            'slug': 'solana',
#            'symbol': 'SOL',
#            'tags': ['dpos',
#                     'platform',
#                     'solana-ecosystem',
#                     'cms-holdings-portfolio',
#                     'kinetic-capital',
#                     'alameda-research-portfolio',
#                     'multicoin-capital-portfolio'],
#            'total_supply': 494519161.74206734},
#           {'circulating_supply': 116313299,
#            'cmc_rank': 19,
#            'date_added': '2016-07-24T00:00:00.000Z',
#            'id': 1321,
#            'last_updated': '2021-05-31T20:02:06.000Z',
#            'max_supply': 210700000,
#            'name': 'Ethereum Classic',
#            'num_market_pairs': 283,
#            'platform': None,
#            'quote': {'USD': {'last_updated': '2021-05-31T20:02:06.000Z',
#                              'market_cap': 7916842520.6682005,
#                              'percent_change_1h': 0.99555666,
#                              'percent_change_24h': 1.63388062,
#                              'percent_change_30d': 58.1968806,
#                              'percent_change_60d': 369.49501116,
#                              'percent_change_7d': 3.77138019,
#                              'percent_change_90d': 535.90586066,
#                              'price': 68.06480934452904,
#                              'volume_24h': 3423484220.842069}},
#            'slug': 'ethereum-classic',
#            'symbol': 'ETC',
#            'tags': ['mineable',
#                     'pow',
#                     'ethash',
#                     'platform',
#                     'smart-contracts',
#                     'dcg-portfolio'],
#            'total_supply': 116313299},
#           {'circulating_supply': 64315576989,
#            'cmc_rank': 20,
#            'date_added': '2017-08-22T00:00:00.000Z',
#            'id': 3077,
#            'last_updated': '2021-05-31T20:02:02.000Z',
#            'max_supply': 86712634466,
#            'name': 'VeChain',
#            'num_market_pairs': 129,
#            'platform': None,
#            'quote': {'USD': {'last_updated': '2021-05-31T20:02:02.000Z',
#                              'market_cap': 7709967963.408459,
#                              'percent_change_1h': 1.66979191,
#                              'percent_change_24h': 10.33188476,
#                              'percent_change_30d': -39.55168269,
#                              'percent_change_60d': 34.7087264,
#                              'percent_change_7d': 4.33269944,
#                              'percent_change_90d': 185.79578651,
#                              'price': 0.11987714834195,
#                              'volume_24h': 1021477442.3117774}},
#            'slug': 'vechain',
#            'symbol': 'VET',
#            'tags': ['logistics',
#                     'data-provenance',
#                     'iot',
#                     'smart-contracts',
#                     'fenbushi-capital-portfolio'],
#            'total_supply': 86712634466},
#           {'circulating_supply': 185810.67863911,
#            'cmc_rank': 21,
#            'date_added': '2019-01-30T00:00:00.000Z',
#            'id': 3717,
#            'last_updated': '2021-05-31T20:01:09.000Z',
#            'max_supply': None,
#            'name': 'Wrapped Bitcoin',
#            'num_market_pairs': 135,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x2260fac5e5542a773aa44fbcfedf7c193bc2c599'},
#            'quote': {'USD': {'last_updated': '2021-05-31T20:01:09.000Z',
#                              'market_cap': 6853571159.897397,
#                              'percent_change_1h': 0.44624561,
#                              'percent_change_24h': 2.0350021,
#                              'percent_change_30d': -36.21220033,
#                              'percent_change_60d': -37.84804876,
#                              'percent_change_7d': -7.13763856,
#                              'percent_change_90d': -22.34743531,
#                              'price': 36884.70011569527,
#                              'volume_24h': 144611883.9901998}},
#            'slug': 'wrapped-bitcoin',
#            'symbol': 'WBTC',
#            'tags': ['medium-of-exchange', 'defi', 'wrapped-tokens'],
#            'total_supply': 185810.67863911},
#           {'circulating_supply': 1000000000,
#            'cmc_rank': 22,
#            'date_added': '2018-01-17T00:00:00.000Z',
#            'id': 2416,
#            'last_updated': '2021-05-31T20:02:05.000Z',
#            'max_supply': 1000000000,
#            'name': 'THETA',
#            'num_market_pairs': 55,
#            'platform': None,
#            'quote': {'USD': {'last_updated': '2021-05-31T20:02:05.000Z',
#                              'market_cap': 6738902689.64805,
#                              'percent_change_1h': 0.90074208,
#                              'percent_change_24h': 1.29704451,
#                              'percent_change_30d': -41.95453996,
#                              'percent_change_60d': -42.48357429,
#                              'percent_change_7d': 0.00447149,
#                              'percent_change_90d': 87.81103566,
#                              'price': 6.73890268964805,
#                              'volume_24h': 262840436.15437555}},
#            'slug': 'theta',
#            'symbol': 'THETA',
#            'tags': ['media',
#                     'collectibles-nfts',
#                     'content-creation',
#                     'video',
#                     'huobi-capital'],
#            'total_supply': 1000000000},
#           {'circulating_supply': 953854914.6325,
#            'cmc_rank': 23,
#            'date_added': '2017-07-01T00:00:00.000Z',
#            'id': 1765,
#            'last_updated': '2021-05-31T20:01:11.000Z',
#            'max_supply': None,
#            'name': 'EOS',
#            'num_market_pairs': 483,
#            'platform': None,
#            'quote': {'USD': {'last_updated': '2021-05-31T20:01:11.000Z',
#                              'market_cap': 5973035811.958412,
#                              'percent_change_1h': 0.81282489,
#                              'percent_change_24h': 1.52177702,
#                              'percent_change_30d': -2.93137521,
#                              'percent_change_60d': 9.25218146,
#                              'percent_change_7d': 17.6329292,
#                              'percent_change_90d': 73.84625255,
#                              'price': 6.26199615930028,
#                              'volume_24h': 2474395876.394703}},
#            'slug': 'eos',
#            'symbol': 'EOS',
#            'tags': ['medium-of-exchange',
#                     'enterprise-solutions',
#                     'smart-contracts',
#                     'binance-chain',
#                     'fenbushi-capital-portfolio',
#                     'galaxy-digital-portfolio'],
#            'total_supply': 1030021992.925},
#           {'circulating_supply': 71659657369.49,
#            'cmc_rank': 24,
#            'date_added': '2017-09-13T00:00:00.000Z',
#            'id': 1958,
#            'last_updated': '2021-05-31T20:01:13.000Z',
#            'max_supply': None,
#            'name': 'TRON',
#            'num_market_pairs': 529,
#            'platform': None,
#            'quote': {'USD': {'last_updated': '2021-05-31T20:01:13.000Z',
#                              'market_cap': 5389663965.56884,
#                              'percent_change_1h': 0.38481126,
#                              'percent_change_24h': 3.69879034,
#                              'percent_change_30d': -41.99465773,
#                              'percent_change_60d': -12.17528478,
#                              'percent_change_7d': -0.33994063,
#                              'percent_change_90d': 63.88652036,
#                              'price': 0.07521196951555,
#                              'volume_24h': 1343205006.0522637}},
#            'slug': 'tron',
#            'symbol': 'TRX',
#            'tags': ['media', 'payments'],
#            'total_supply': 100850743811.662},
#           {'circulating_supply': 74994605,
#            'cmc_rank': 25,
#            'date_added': '2017-12-13T00:00:00.000Z',
#            'id': 2280,
#            'last_updated': '2021-05-31T20:02:05.000Z',
#            'max_supply': None,
#            'name': 'Filecoin',
#            'num_market_pairs': 127,
#            'platform': None,
#            'quote': {'USD': {'last_updated': '2021-05-31T20:02:05.000Z',
#                              'market_cap': 5308208749.151788,
#                              'percent_change_1h': 0.67028526,
#                              'percent_change_24h': 3.903526,
#                              'percent_change_30d': -56.49866187,
#                              'percent_change_60d': -64.70897928,
#                              'percent_change_7d': -2.89193683,
#                              'percent_change_90d': 88.05300782,
#                              'price': 70.78120818359918,
#                              'volume_24h': 791369075.4284358}},
#            'slug': 'filecoin',
#            'symbol': 'FIL',
#            'tags': ['mineable',
#                     'distributed-computing',
#                     'filesharing',
#                     'storage',
#                     'polychain-capital-portfolio',
#                     'blockchain-capital-portfolio',
#                     'boostvc-portfolio',
#                     'dcg-portfolio',
#                     'hashkey-capital-portfolio',
#                     'a16z-portfolio',
#                     'winklevoss-capital',
#                     'pantera-capital-portfolio'],
#            'total_supply': 74994605},
#           {'circulating_supply': 4663144957.666943,
#            'cmc_rank': 26,
#            'date_added': '2019-11-22T00:00:00.000Z',
#            'id': 4943,
#            'last_updated': '2021-05-31T20:01:09.000Z',
#            'max_supply': None,
#            'name': 'Dai',
#            'num_market_pairs': 468,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x6b175474e89094c44da98b954eedeac495271d0f'},
#            'quote': {'USD': {'last_updated': '2021-05-31T20:01:09.000Z',
#                              'market_cap': 4669205923.773731,
#                              'percent_change_1h': -0.03470961,
#                              'percent_change_24h': 0.06797524,
#                              'percent_change_30d': 0.04861575,
#                              'percent_change_60d': -0.34941869,
#                              'percent_change_7d': -0.10112503,
#                              'percent_change_90d': 0.01802082,
#                              'price': 1.00129975931733,
#                              'volume_24h': 360485933.58007467}},
#            'slug': 'multi-collateral-dai',
#            'symbol': 'DAI',
#            'tags': ['defi', 'stablecoin'],
#            'total_supply': 4663145446.506087},
#           {'circulating_supply': 12785452.23252466,
#            'cmc_rank': 27,
#            'date_added': '2020-10-02T00:00:00.000Z',
#            'id': 7278,
#            'last_updated': '2021-05-31T20:02:03.000Z',
#            'max_supply': 16000000,
#            'name': 'Aave',
#            'num_market_pairs': 213,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x7Fc66500c84A76Ad7e9c93437bFc5Ac33E2DDaE9'},
#            'quote': {'USD': {'last_updated': '2021-05-31T20:02:03.000Z',
#                              'market_cap': 4666755209.20953,
#                              'percent_change_1h': 1.54331326,
#                              'percent_change_24h': 8.90932507,
#                              'percent_change_30d': -27.50990653,
#                              'percent_change_60d': -3.6819935,
#                              'percent_change_7d': -6.46709503,
#                              'percent_change_90d': -5.22147751,
#                              'price': 365.0050951923205,
#                              'volume_24h': 628523979.1942971}},
#            'slug': 'aave',
#            'symbol': 'AAVE',
#            'tags': ['defi',
#                     'dao',
#                     'yield-farming',
#                     'three-arrows-capital-portfolio',
#                     'governance',
#                     'lending-borowing',
#                     'blockchain-capital-portfolio',
#                     'defiance-capital',
#                     'framework-ventures',
#                     'alameda-research-portfolio',
#                     'pantera-capital-portfolio',
#                     'parafi-capital',
#                     'polygon-ecosystem'],
#            'total_supply': 16000000},
#           {'circulating_supply': 17921794.43199179,
#            'cmc_rank': 28,
#            'date_added': '2014-05-21T00:00:00.000Z',
#            'id': 328,
#            'last_updated': '2021-05-31T20:02:05.000Z',
#            'max_supply': None,
#            'name': 'Monero',
#            'num_market_pairs': 178,
#            'platform': None,
#            'quote': {'USD': {'last_updated': '2021-05-31T20:02:05.000Z',
#                              'market_cap': 4672939922.397146,
#                              'percent_change_1h': 0.16641882,
#                              'percent_change_24h': -0.87052689,
#                              'percent_change_30d': -38.88805573,
#                              'percent_change_60d': 3.7523714,
#                              'percent_change_7d': 4.14211484,
#                              'percent_change_90d': 22.27191291,
#                              'price': 260.74062729207446,
#                              'volume_24h': 269976003.12347585}},
#            'slug': 'monero',
#            'symbol': 'XMR',
#            'tags': ['mineable',
#                     'pow',
#                     'medium-of-exchange',
#                     'privacy',
#                     'ringct',
#                     'boostvc-portfolio',
#                     'electric-capital-portfolio',
#                     'galaxy-digital-portfolio'],
#            'total_supply': 17921794.43199179},
#           {'circulating_supply': 70538831,
#            'cmc_rank': 29,
#            'date_added': '2016-09-08T00:00:00.000Z',
#            'id': 1376,
#            'last_updated': '2021-05-31T20:02:05.000Z',
#            'max_supply': 100000000,
#            'name': 'Neo',
#            'num_market_pairs': 267,
#            'platform': None,
#            'quote': {'USD': {'last_updated': '2021-05-31T20:02:05.000Z',
#                              'market_cap': 3807605963.9248743,
#                              'percent_change_1h': 0.84796133,
#                              'percent_change_24h': 2.57245236,
#                              'percent_change_30d': -44.1351617,
#                              'percent_change_60d': 1.99528095,
#                              'percent_change_7d': 2.31658104,
#                              'percent_change_90d': 47.52815454,
#                              'price': 53.97886398095929,
#                              'volume_24h': 496645981.80720925}},
#            'slug': 'neo',
#            'symbol': 'NEO',
#            'tags': ['platform', 'enterprise-solutions', 'smart-contracts'],
#            'total_supply': 100000000},
#           {'circulating_supply': 991501.05397005,
#            'cmc_rank': 30,
#            'date_added': '2017-01-29T00:00:00.000Z',
#            'id': 1518,
#            'last_updated': '2021-05-31T20:02:07.000Z',
#            'max_supply': 1005577,
#            'name': 'Maker',
#            'num_market_pairs': 217,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x9f8f72aa9304c8b593d555f12ef6589cc3a579a2'},
#            'quote': {'USD': {'last_updated': '2021-05-31T20:02:07.000Z',
#                              'market_cap': 3503792560.5214176,
#                              'percent_change_1h': 1.06408179,
#                              'percent_change_24h': 4.79327125,
#                              'percent_change_30d': -28.334822,
#                              'percent_change_60d': 57.18181906,
#                              'percent_change_7d': -9.93046775,
#                              'percent_change_90d': 67.56461497,
#                              'price': 3533.8263600345663,
#                              'volume_24h': 201180725.89271337}},
#            'slug': 'maker',
#            'symbol': 'MKR',
#            'tags': ['store-of-value',
#                     'defi',
#                     'dao',
#                     'polychain-capital-portfolio',
#                     'governance',
#                     'lending-borowing',
#                     'dragonfly-capital-portfolio',
#                     'electric-capital-portfolio',
#                     'a16z-portfolio',
#                     '1confirmation-portfolio',
#                     'placeholder-ventures-portfolio',
#                     'pantera-capital-portfolio',
#                     'paradigm-xzy-screener'],
#            'total_supply': 991501.05397005},
#           {'circulating_supply': 394796000000000,
#            'cmc_rank': 31,
#            'date_added': '2020-08-01T00:00:00.000Z',
#            'id': 5994,
#            'last_updated': '2021-05-31T20:01:09.000Z',
#            'max_supply': None,
#            'name': 'SHIBA INU',
#            'num_market_pairs': 85,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#            'quote': {'USD': {'last_updated': '2021-05-31T20:01:09.000Z',
#                              'market_cap': 3482273526.15716,
#                              'percent_change_1h': 0.39111062,
#                              'percent_change_24h': 10.91633503,
#                              'percent_change_30d': 368.19904203,
#                              'percent_change_60d': 16488.797307,
#                              'percent_change_7d': -20.29250391,
#                              'percent_change_90d': 55396.47508227,
#                              'price': 8.82043771e-06,
#                              'volume_24h': 671769492.6617683}},
#            'slug': 'shiba-inu',
#            'symbol': 'SHIB',
#            'tags': ['memes'],
#            'total_supply': 1000000000000000},
#           {'circulating_supply': 2468999159.4,
#            'cmc_rank': 32,
#            'date_added': '2020-03-30T00:00:00.000Z',
#            'id': 4256,
#            'last_updated': '2021-05-31T20:02:03.000Z',
#            'max_supply': None,
#            'name': 'Klaytn',
#            'num_market_pairs': 46,
#            'platform': None,
#            'quote': {'USD': {'last_updated': '2021-05-31T20:02:03.000Z',
#                              'market_cap': 3415863706.111616,
#                              'percent_change_1h': 0.34441866,
#                              'percent_change_24h': -0.90985698,
#                              'percent_change_30d': -40.85836211,
#                              'percent_change_60d': -66.27969064,
#                              'percent_change_7d': -2.91932459,
#                              'percent_change_90d': -3.62548271,
#                              'price': 1.38350136455361,
#                              'volume_24h': 40984935.19658875}},
#            'slug': 'klaytn',
#            'symbol': 'KLAY',
#            'tags': ['platform', 'enterprise-solutions'],
#            'total_supply': 10583317350.4},
#           {'circulating_supply': 18747801.64423905,
#            'cmc_rank': 33,
#            'date_added': '2018-11-09T00:00:00.000Z',
#            'id': 3602,
#            'last_updated': '2021-05-31T20:01:07.000Z',
#            'max_supply': 21000000,
#            'name': 'Bitcoin SV',
#            'num_market_pairs': 212,
#            'platform': None,
#            'quote': {'USD': {'last_updated': '2021-05-31T20:01:07.000Z',
#                              'market_cap': 3227033180.997183,
#                              'percent_change_1h': 0.47758078,
#                              'percent_change_24h': 2.57989696,
#                              'percent_change_30d': -48.55969213,
#                              'percent_change_60d': -26.30300996,
#                              'percent_change_7d': -2.37664105,
# ...
#            'slug': 'covesting',
#            'symbol': 'COV',
#            'tags': ['asset-management'],
#            'total_supply': 20000000},
#           {'circulating_supply': 1788038022.4,
#            'cmc_rank': 989,
#            'date_added': '2019-04-23T00:00:00.000Z',
#            'id': 3880,
#            'last_updated': '2021-05-31T20:01:11.000Z',
#            'max_supply': None,
#            'name': 'OceanEx Token',
#            'num_market_pairs': 5,
#            'platform': None,
#            'quote': {'USD': {'last_updated': '2021-05-31T20:01:11.000Z',
#                              'market_cap': 8180101.86445917,
#                              'percent_change_1h': 0.12272512,
#                              'percent_change_24h': 8.72154516,
#                              'percent_change_30d': -63.89239034,
#                              'percent_change_60d': -29.02371015,
#                              'percent_change_7d': -11.73506671,
#                              'percent_change_90d': 130.38604355,
#                              'price': 0.00457490375595,
#                              'volume_24h': 242795.1112125}},
#            'slug': 'oceanex-token',
#            'symbol': 'OCE',
#            'tags': [],
#            'total_supply': 8811756112.4},
#           {'circulating_supply': 10852777.67201144,
#            'cmc_rank': 990,
#            'date_added': '2021-04-08T00:00:00.000Z',
#            'id': 9175,
#            'last_updated': '2021-05-31T20:01:13.000Z',
#            'max_supply': 1000000000,
#            'name': 'MOBOX',
#            'num_market_pairs': 9,
#            'platform': {'id': 1839,
#                         'name': 'Binance Smart Chain',
#                         'slug': 'binance-coin',
#                         'symbol': 'BNB',
#                         'token_address': '0x3203c9e46ca618c8c1ce5dc67e7e9d75f5da2377'},
#            'quote': {'USD': {'last_updated': '2021-05-31T20:01:13.000Z',
#                              'market_cap': 8185794.422981043,
#                              'percent_change_1h': 0.30394036,
#                              'percent_change_24h': 7.35216825,
#                              'percent_change_30d': -49.78651253,
#                              'percent_change_60d': 0,
#                              'percent_change_7d': -13.01448854,
#                              'percent_change_90d': 0,
#                              'price': 0.75425800383727,
#                              'volume_24h': 2069344.30495926}},
#            'slug': 'mobox',
#            'symbol': 'MBOX',
#            'tags': ['collectibles-nfts',
#                     'defi',
#                     'yield-farming',
#                     'binance-smart-chain'],
#            'total_supply': 399912971.20308584},
#           {'circulating_supply': 88242934.36144884,
#            'cmc_rank': 991,
#            'date_added': '2021-02-01T00:00:00.000Z',
#            'id': 8366,
#            'last_updated': '2021-05-31T20:02:04.000Z',
#            'max_supply': None,
#            'name': 'World Token',
#            'num_market_pairs': 3,
#            'platform': None,
#            'quote': {'USD': {'last_updated': '2021-05-31T20:02:04.000Z',
#                              'market_cap': 8222424.292333549,
#                              'percent_change_1h': 1.82992744,
#                              'percent_change_24h': 26.52369232,
#                              'percent_change_30d': -4.46503557,
#                              'percent_change_60d': -29.48947172,
#                              'percent_change_7d': 1.79729051,
#                              'percent_change_90d': 47.74730962,
#                              'price': 0.0931794069614,
#                              'volume_24h': 310988.40509064}},
#            'slug': 'world-token',
#            'symbol': 'WORLD',
#            'tags': [],
#            'total_supply': 100000000},
#           {'circulating_supply': 184346234.807425,
#            'cmc_rank': 992,
#            'date_added': '2020-11-26T00:00:00.000Z',
#            'id': 7784,
#            'last_updated': '2021-05-31T20:02:07.000Z',
#            'max_supply': 999999999,
#            'name': 'BLink',
#            'num_market_pairs': 1,
#            'platform': {'id': 1839,
#                         'name': 'Binance Smart Chain',
#                         'slug': 'binance-coin',
#                         'symbol': 'BNB',
#                         'token_address': '0x63870a18b6e42b01ef1ad8a2302ef50b7132054f'},
#            'quote': {'USD': {'last_updated': '2021-05-31T20:02:07.000Z',
#                              'market_cap': 8155217.687829483,
#                              'percent_change_1h': 0.40169674,
#                              'percent_change_24h': 1.9276098,
#                              'percent_change_30d': -67.16723208,
#                              'percent_change_60d': 27.42306799,
#                              'percent_change_7d': -22.28520469,
#                              'percent_change_90d': 92.39007636,
#                              'price': 0.04423859102058,
#                              'volume_24h': 5859.90636628}},
#            'slug': 'blink',
#            'symbol': 'BLINK',
#            'tags': [],
#            'total_supply': 999999999},
#           {'circulating_supply': 50010379197.94551,
#            'cmc_rank': 993,
#            'date_added': '2018-11-02T00:00:00.000Z',
#            'id': 3589,
#            'last_updated': '2021-05-31T20:01:08.000Z',
#            'max_supply': 99000000000,
#            'name': 'Ethereum Meta',
#            'num_market_pairs': 4,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x340ef83ec8560892168d4062720f030460468656'},
#            'quote': {'USD': {'last_updated': '2021-05-31T20:01:08.000Z',
#                              'market_cap': 8124065.178109867,
#                              'percent_change_1h': 1.05803965,
#                              'percent_change_24h': 27.27032129,
#                              'percent_change_30d': 57.73375881,
#                              'percent_change_60d': 2006.50400341,
#                              'percent_change_7d': -39.62329029,
#                              'percent_change_90d': 2020.25365292,
#                              'price': 0.00016244758205,
#                              'volume_24h': 17522.91162346}},
#            'slug': 'ethereum-meta',
#            'symbol': 'ETHM',
#            'tags': [],
#            'total_supply': 99000000000},
#           {'circulating_supply': 8856541707.22174,
#            'cmc_rank': 994,
#            'date_added': '2019-06-26T00:00:00.000Z',
#            'id': 4054,
#            'last_updated': '2021-05-31T20:01:13.000Z',
#            'max_supply': None,
#            'name': 'IG Gold',
#            'num_market_pairs': 6,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x8ffe40a3d0f80c0ce6b203d5cdc1a6a86d9acaea'},
#            'quote': {'USD': {'last_updated': '2021-05-31T20:01:13.000Z',
#                              'market_cap': 8121013.78579154,
#                              'percent_change_1h': 0.8452185,
#                              'percent_change_24h': -6.65493452,
#                              'percent_change_30d': -66.30058038,
#                              'percent_change_60d': -30.68818038,
#                              'percent_change_7d': -22.97345922,
#                              'percent_change_90d': 214.27177829,
#                              'price': 0.00091695088831,
#                              'volume_24h': 35994.93332248}},
#            'slug': 'ig-gold',
#            'symbol': 'IGG',
#            'tags': [],
#            'total_supply': 48132126676},
#           {'circulating_supply': 284742627.99294,
#            'cmc_rank': 995,
#            'date_added': '2018-01-24T00:00:00.000Z',
#            'id': 2455,
#            'last_updated': '2021-05-31T20:02:07.000Z',
#            'max_supply': 2000000000,
#            'name': 'PressOne',
#            'num_market_pairs': 5,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0xe0d95530820aafc51b1d98023aa1ff000b78d8b2'},
#            'quote': {'USD': {'last_updated': '2021-05-31T20:02:07.000Z',
#                              'market_cap': 8099806.19748014,
#                              'percent_change_1h': 1.0514332,
#                              'percent_change_24h': 6.94987119,
#                              'percent_change_30d': -19.14673434,
#                              'percent_change_60d': -48.89088499,
#                              'percent_change_7d': 21.19889506,
#                              'percent_change_90d': 76.33681352,
#                              'price': 0.02844606111341,
#                              'volume_24h': 895.63059861}},
#            'slug': 'pressone',
#            'symbol': 'PRS',
#            'tags': ['marketplace', 'content-creation'],
#            'total_supply': 2000000000},
#           {'circulating_supply': 61440000000,
#            'cmc_rank': 996,
#            'date_added': '2018-08-16T00:00:00.000Z',
#            'id': 3182,
#            'last_updated': '2021-05-31T20:02:03.000Z',
#            'max_supply': None,
#            'name': 'HitChain',
#            'num_market_pairs': 8,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x7995ab36bB307Afa6A683C24a25d90Dc1Ea83566'},
#            'quote': {'USD': {'last_updated': '2021-05-31T20:02:03.000Z',
#                              'market_cap': 8006819.60448,
#                              'percent_change_1h': -0.43233215,
#                              'percent_change_24h': 0.92207979,
#                              'percent_change_30d': -71.97236932,
#                              'percent_change_60d': -24.8420237,
#                              'percent_change_7d': -6.49097764,
#                              'percent_change_90d': 65.13380271,
#                              'price': 0.0001303193295,
#                              'volume_24h': 375841.27867076}},
#            'slug': 'hitchain',
#            'symbol': 'HIT',
#            'tags': [],
#            'total_supply': 102400000000},
#           {'circulating_supply': 2357575088,
#            'cmc_rank': 997,
#            'date_added': '2019-09-25T00:00:00.000Z',
#            'id': 4144,
#            'last_updated': '2021-05-31T20:02:03.000Z',
#            'max_supply': 5000000000,
#            'name': 'TrueFeedBack',
#            'num_market_pairs': 2,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x4057db5bd9f67a566aa10e5587b1a964affc6a16'},
#            'quote': {'USD': {'last_updated': '2021-05-31T20:02:03.000Z',
#                              'market_cap': 8020394.054064909,
#                              'percent_change_1h': 3.31785696,
#                              'percent_change_24h': -15.6032349,
#                              'percent_change_30d': -77.42612789,
#                              'percent_change_60d': -49.77530802,
#                              'percent_change_7d': 25.37474265,
#                              'percent_change_90d': 205.58114635,
#                              'price': 0.00340196759581,
#                              'volume_24h': 313986.37270133}},
#            'slug': 'truefeedback',
#            'symbol': 'TFBX',
#            'tags': [],
#            'total_supply': 5000000000},
#           {'circulating_supply': 287573453.4014902,
#            'cmc_rank': 998,
#            'date_added': '2020-11-25T00:00:00.000Z',
#            'id': 7772,
#            'last_updated': '2021-05-31T20:01:08.000Z',
#            'max_supply': None,
#            'name': 'Leverj Gluon',
#            'num_market_pairs': 8,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0xBbff34E47E559ef680067a6B1c980639EEb64D24'},
#            'quote': {'USD': {'last_updated': '2021-05-31T20:01:08.000Z',
#                              'market_cap': 8033315.373450226,
#                              'percent_change_1h': 0.01858752,
#                              'percent_change_24h': -2.14738115,
#                              'percent_change_30d': -65.67688525,
#                              'percent_change_60d': -49.93762382,
#                              'percent_change_7d': -6.60784413,
#                              'percent_change_90d': -56.03289627,
#                              'price': 0.0279348294442,
#                              'volume_24h': 80421.09022556}},
#            'slug': 'leverj-gluon',
#            'symbol': 'L2',
#            'tags': ['defi'],
#            'total_supply': 835840097.1628854},
#           {'circulating_supply': 250000000,
#            'cmc_rank': 999,
#            'date_added': '2021-01-02T00:00:00.000Z',
#            'id': 8162,
#            'last_updated': '2021-05-31T20:01:13.000Z',
#            'max_supply': 1500000000,
#            'name': 'AMEPAY',
#            'num_market_pairs': 6,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x12513335ffD5DAfc2334e98625d27c1CA84bff86'},
#            'quote': {'USD': {'last_updated': '2021-05-31T20:01:13.000Z',
#                              'market_cap': 7999321.4438675,
#                              'percent_change_1h': -1.49316048,
#                              'percent_change_24h': 1.69366369,
#                              'percent_change_30d': -52.72957042,
#                              'percent_change_60d': -55.07689636,
#                              'percent_change_7d': -3.47603421,
#                              'percent_change_90d': -69.23388739,
#                              'price': 0.03199728577547,
#                              'volume_24h': 109533.2280321}},
#            'slug': 'amepay',
#            'symbol': 'AME',
#            'tags': [],
#            'total_supply': 250000000},
#           {'circulating_supply': 1310099624.0728,
#            'cmc_rank': 1000,
#            'date_added': '2017-12-13T00:00:00.000Z',
#            'id': 2274,
#            'last_updated': '2021-05-31T20:02:04.000Z',
#            'max_supply': None,
#            'name': 'MediShares',
#            'num_market_pairs': 8,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x66186008C1050627F979d464eABb258860563dbE'},
#            'quote': {'USD': {'last_updated': '2021-05-31T20:02:04.000Z',
#                              'market_cap': 8006886.167894841,
#                              'percent_change_1h': -0.06177806,
#                              'percent_change_24h': -0.74210582,
#                              'percent_change_30d': -63.01418458,
#                              'percent_change_60d': -52.28018217,
#                              'percent_change_7d': -10.65505806,
#                              'percent_change_90d': 31.32686107,
#                              'price': 0.00611166206048,
#                              'volume_24h': 462825.84246818}},
#            'slug': 'medishares',
#            'symbol': 'MDS',
#            'tags': ['health'],
#            'total_supply': 2000000000}],
#  'status': {'credit_count': 5,
#             'elapsed': 112,
#             'error_code': 0,
#             'error_message': None,
#             'notice': None,
#             'timestamp': '2021-05-31T20:03:07.421Z',
#             'total_count': 5430}}

# %%
pprint.pprint(data1['data'][0])
# Out:
# {'circulating_supply': 18723018,
#  'cmc_rank': 1,
#  'date_added': '2013-04-28T00:00:00.000Z',
#  'id': 1,
#  'last_updated': '2021-05-31T20:02:02.000Z',
#  'max_supply': 21000000,
#  'name': 'Bitcoin',
#  'num_market_pairs': 9738,
#  'platform': None,
#  'quote': {'USD': {'last_updated': '2021-05-31T20:02:02.000Z',
#                    'market_cap': 691343040707.2864,
#                    'percent_change_1h': 0.47006729,
#                    'percent_change_24h': 2.39924732,
#                    'percent_change_30d': -36.08665245,
#                    'percent_change_60d': -37.70336787,
#                    'percent_change_7d': -7.30604886,
#                    'percent_change_90d': -22.31800034,
#                    'price': 36924.76505162183,
#                    'volume_24h': 37958553656.49961}},
#  'slug': 'bitcoin',
#  'symbol': 'BTC',
#  'tags': ['mineable',
#           'pow',
#           'sha-256',
#           'store-of-value',
#           'state-channels',
#           'coinbase-ventures-portfolio',
#           'three-arrows-capital-portfolio',
#           'polychain-capital-portfolio',
#           'binance-labs-portfolio',
#           'arrington-xrp-capital',
#           'blockchain-capital-portfolio',
#           'boostvc-portfolio',
#           'cms-holdings-portfolio',
#           'dcg-portfolio',
#           'dragonfly-capital-portfolio',
#           'electric-capital-portfolio',
#           'fabric-ventures-portfolio',
#           'framework-ventures',
#           'galaxy-digital-portfolio',
#           'huobi-capital',
#           'alameda-research-portfolio',
#           'a16z-portfolio',
#           '1confirmation-portfolio',
#           'winklevoss-capital',
#           'usv-portfolio',
#           'placeholder-ventures-portfolio',
#           'pantera-capital-portfolio',
#           'multicoin-capital-portfolio',
#           'paradigm-xzy-screener'],
#  'total_supply': 18723018}
