# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/ancha/OneDrive/Desktop/vs_code/Financial_Sample.csv")
df.head()
# Out:
#       Segment  Country      Product Discount_Band  Units_Sold  \
# 0  Government   Canada   Carretera          None       1618.5
# 1  Government  Germany   Carretera          None       1321.0
# 2   Midmarket   France   Carretera          None       2178.0
# 3   Midmarket  Germany   Carretera          None        888.0
# 4   Midmarket   Mexico   Carretera          None       2470.0
#
#   Manufacturing_Price Sale_Price   Gross_Sales Discounts         Sales  \
# 0              $3.00     $20.00    $32,370.00        NaN   $32,370.00
# 1              $3.00     $20.00    $26,420.00        NaN   $26,420.00
# 2              $3.00     $15.00    $32,670.00        NaN   $32,670.00
# 3              $3.00     $15.00    $13,320.00        NaN   $13,320.00
# 4              $3.00     $15.00    $37,050.00        NaN   $37,050.00
#
#            COGS        Profit        Date  Month_Number Month_Name  Year
# 0   $16,185.00    $16,185.00   01/01/2014             1   January   2014
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Segment              700 non-null    object
#  1   Country              700 non-null    object
#  2   Product              700 non-null    object
#  3   Discount_Band        700 non-null    object
#  4   Units_Sold           700 non-null    float64
#  5   Manufacturing_Price  700 non-null    object
#  6   Sale_Price           700 non-null    object
#  7   Gross_Sales          700 non-null    object
#  8   Discounts            647 non-null    object
#  9   Sales                700 non-null    object
#  10  COGS                 700 non-null    object
#  11  Profit               695 non-null    object
#  12  Date                 700 non-null    object
#  13  Month_Number         700 non-null    int64
#  14  Month_Name           700 non-null    object
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=700, step=1)

# %%
df.describe()
# Out:
#         Units_Sold  Month_Number         Year
# count   700.000000    700.000000   700.000000
# mean   1608.294286      7.900000  2013.750000
# std     867.427859      3.377321     0.433322
# min     200.000000      1.000000  2013.000000
# 25%     905.000000      5.750000  2013.750000
# 50%    1542.500000      9.000000  2014.000000
# 75%    2229.125000     10.250000  2014.000000
# max    4492.500000     12.000000  2014.000000

# %%
df.columns
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount_Band', 'Units_Sold',
#        'Manufacturing_Price', 'Sale_Price', 'Gross_Sales', 'Discounts',
#        'Sales', 'COGS', 'Profit', 'Date', 'Month_Number', 'Month_Name',
#        'Year'],
#       dtype='object')

# %%
df.Segment.unique()
# Out:
# array(['Government', 'Midmarket', 'Channel Partners', 'Enterprise',
#        'Small Business'], dtype=object)

# %%
df.Segment = df.Segment.str.lower()
df.Segment.unique()
# Out:
# array(['government', 'midmarket', 'channel partners', 'enterprise',
#        'small business'], dtype=object)

# %%
df.head(1)
# Out:
#       Segment Country      Product Discount_Band  Units_Sold  \
# 0  government  Canada   Carretera          None       1618.5
#
#   Manufacturing_Price Sale_Price   Gross_Sales Discounts         Sales  \
# 0              $3.00     $20.00    $32,370.00        NaN   $32,370.00
#
#            COGS        Profit        Date  Month_Number Month_Name  Year
# 0   $16,185.00    $16,185.00   01/01/2014             1   January   2014

# %%
df['manufacturing_price'] = df['Manufacturing_Price'].str[2:]
df['manufacturing_price']
# Out:
# 0        3.00
# 1        3.00
# 2        3.00
# 3        3.00
# 4        3.00
#         ...
# 695    260.00
# 696    260.00
# 697      5.00
# 698     10.00
# 699    250.00
# Name: manufacturing_price, Length: 700, dtype: object

# %%
df.head(1)
# Out:
#       Segment Country      Product Discount_Band  Units_Sold  \
# 0  government  Canada   Carretera          None       1618.5
#
#   Manufacturing_Price Sale_Price   Gross_Sales Discounts         Sales  \
# 0              $3.00     $20.00    $32,370.00        NaN   $32,370.00
#
#            COGS        Profit        Date  Month_Number Month_Name  Year  \
# 0   $16,185.00    $16,185.00   01/01/2014             1   January   2014
#
#   manufacturing_price
# 0               3.00

# %%
df['sale_price'] = df['Sale_Price'].str[2:]

# %%
df.head(1)
# Out:
#       Segment Country      Product Discount_Band  Units_Sold  \
# 0  government  Canada   Carretera          None       1618.5
#
#   Manufacturing_Price Sale_Price   Gross_Sales Discounts         Sales  \
# 0              $3.00     $20.00    $32,370.00        NaN   $32,370.00
#
#            COGS        Profit        Date  Month_Number Month_Name  Year  \
# 0   $16,185.00    $16,185.00   01/01/2014             1   January   2014
#
#   manufacturing_price sale_price
# 0               3.00      20.00

# %%
df['manufacturing_price'].dtype
# Out:
# dtype('O')

# %%
df['gross_sales'] = df['Gross_Sales'].str[2:]

# %%
df.head(1)
# Out:
#       Segment Country      Product Discount_Band  Units_Sold  \
# 0  government  Canada   Carretera          None       1618.5
#
#   Manufacturing_Price Sale_Price   Gross_Sales Discounts         Sales  \
# 0              $3.00     $20.00    $32,370.00        NaN   $32,370.00
#
#            COGS        Profit        Date  Month_Number Month_Name  Year  \
# 0   $16,185.00    $16,185.00   01/01/2014             1   January   2014
#
#   manufacturing_price sale_price gross_sales
# 0               3.00      20.00   32,370.00

# %%
df['sales'] = df['Sales'].str[2:]

# %%
df['cogs'] = df['COGS'].str[2:]

# %%
df['profit'] = df['Profit'].str[2:]

# %%
df['discounts'] = df['Discounts'].str[2:]

# %%
df.head(2)
# Out:
#       Segment  Country      Product Discount_Band  Units_Sold  \
# 0  government   Canada   Carretera          None       1618.5
# 1  government  Germany   Carretera          None       1321.0
#
#   Manufacturing_Price Sale_Price   Gross_Sales Discounts         Sales  ...  \
# 0              $3.00     $20.00    $32,370.00        NaN   $32,370.00   ...
# 1              $3.00     $20.00    $26,420.00        NaN   $26,420.00   ...
#
#   Month_Number Month_Name  Year  manufacturing_price sale_price  gross_sales  \
# 0            1   January   2014                3.00      20.00    32,370.00
# 1            1   January   2014                3.00      20.00    26,420.00
#
#         sales        cogs      profit discounts
# 0  32,370.00   16,185.00   16,185.00        NaN
# 1  26,420.00   13,210.00   13,210.00        NaN
#
# [2 rows x 23 columns]

# %%
 df['manufacturing_price'] = pd.to_numeric(df['manufacturing_price'])

# %%
df['sales_price'] = pd.to_numeric(df['sale_price'])
df['sales_price']
# Out:
# 0       20.0
# 1       20.0
# 2       15.0
# 3       15.0
# 4       15.0
#        ...
# 695    300.0
# 696    300.0
# 697      7.0
# 698      7.0
# 699     12.0
# Name: sales_price, Length: 700, dtype: float64

# %%
df['sales'] = df['sales'].str.replace(',', '')

df['gross_sales'] = df['gross_sales'].str.replace(',', '')

df['cogs'] = df['cogs'].str.replace(',', '')

# %%
df['discounts'] = df['discounts'].str.replace(',', '')
df['discounts'] = df['discounts'].str.replace('-', '')

# %%
df['profit'] = df['profit'].str.replace(',', '')

# %%
df
# Out:
#               Segment                   Country      Product Discount_Band  \
# 0          government                    Canada   Carretera          None
# 1          government                   Germany   Carretera          None
# 2           midmarket                    France   Carretera          None
# 3           midmarket                   Germany   Carretera          None
# 4           midmarket                    Mexico   Carretera          None
# ..                ...                       ...          ...           ...
# 695    small business                    France    Amarilla          High
# 696    small business                    Mexico    Amarilla          High
# 697        government                    Mexico     Montana          High
# 698        government                    Canada       Paseo          High
# 699  channel partners  United States of America         VTT          High
#
# ...

# %%
df['gross_sales'] = pd.to_numeric(df['gross_sales'])


df['cogs'] = pd.to_numeric(df['cogs'])

# %%
df['sales'] = pd.to_numeric(df['sales'])
df['sales']
# Out:
# 0       32370.00
# 1       26420.00
# 2       32670.00
# 3       13320.00
# 4       37050.00
#          ...
# 695    631125.00
# 696    139230.00
# 697      8139.60
# 698      4301.85
# 699     18421.20
# Name: sales, Length: 700, dtype: float64

# %%
df['discounts'].isnull().sum()
# Out:
# 53

# %%
df['discounts']
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 695    111375.00
# 696     24570.00
# 697      1436.40
# 698       759.15
# 699      3250.80
# Name: discounts, Length: 700, dtype: object

# %%
df['discounts'] = df['discounts'].fillna(0)

# %%
df['discounts']
# Out:
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
#           ...
# 695    111375.00
# 696     24570.00
# 697      1436.40
# 698       759.15
# 699      3250.80
# Name: discounts, Length: 700, dtype: object

# %%
df['discounts'] = pd.to_numeric(df['discounts'])

# %%
df['profit'].isnull().sum()
# Out:
# 5

# %%
df['profit'] = df['profit'].fillna(0)

# %%
df['profit'] = pd.to_numeric(df['profit'])

# %%
df['profit'].describe()
# Out:
# count       700.000000
# mean      26354.778271
# std       41426.798657
# min           0.000000
# 25%        3815.707500
# 50%       11110.550000
# 75%       23756.360000
# max      262200.000000
# Name: profit, dtype: float64

# %%
df2 = df.drop(['Manufacturing_Price', 'Sale_Price', 'Gross_Sales', 'Discounts', 'Sales', 'COGS', 'Profit', 'sale_price'], axis = 1)

# %%
df2
# Out:
#               Segment                   Country      Product Discount_Band  \
# 0          government                    Canada   Carretera          None
# 1          government                   Germany   Carretera          None
# 2           midmarket                    France   Carretera          None
# 3           midmarket                   Germany   Carretera          None
# 4           midmarket                    Mexico   Carretera          None
# ..                ...                       ...          ...           ...
# 695    small business                    France    Amarilla          High
# 696    small business                    Mexico    Amarilla          High
# 697        government                    Mexico     Montana          High
# 698        government                    Canada       Paseo          High
# 699  channel partners  United States of America         VTT          High
#
#      Units_Sold        Date  Month_Number  Month_Name  Year  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Segment              700 non-null    object
#  1   Country              700 non-null    object
#  2   Product              700 non-null    object
#  3   Discount_Band        700 non-null    object
#  4   Units_Sold           700 non-null    float64
#  5   Date                 700 non-null    object
#  6   Month_Number         700 non-null    int64
#  7   Month_Name           700 non-null    object
#  8   Year                 700 non-null    int64
#  9   manufacturing_price  700 non-null    float64
#  10  gross_sales          700 non-null    float64
#  11  sales                700 non-null    float64
#  12  cogs                 700 non-null    float64
#  13  profit               700 non-null    float64
#  14  discounts            700 non-null    float64
# ...

# %%
df2.to_csv("C:/Users/ancha/OneDrive/Desktop/vs_code/fin_data.csv")

# %%
df2.describe()
# Out:
#         Units_Sold  Month_Number         Year  manufacturing_price  \
# count   700.000000    700.000000   700.000000           700.000000
# mean   1608.294286      7.900000  2013.750000            96.477143
# std     867.427859      3.377321     0.433322           108.602612
# min     200.000000      1.000000  2013.000000             3.000000
# 25%     905.000000      5.750000  2013.750000             5.000000
# 50%    1542.500000      9.000000  2014.000000            10.000000
# 75%    2229.125000     10.250000  2014.000000           250.000000
# max    4492.500000     12.000000  2014.000000           260.000000
#
#         gross_sales         sales           cogs         profit  \
# count  7.000000e+02  7.000000e+02     700.000000     700.000000
# mean   1.827594e+05  1.696091e+05  145475.211429   26354.778271
# std    2.542623e+05  2.367263e+05  203865.506118   41426.798657
# min    1.799000e+03  1.655080e+03     918.000000       0.000000
# ...
